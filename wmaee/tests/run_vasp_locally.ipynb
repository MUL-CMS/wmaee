# %%
from wmaee.core.interfaces.calculation import VaspCalculation
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/david/Software/wmaee/wmaee/tests/run_vasp_locally.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/home/david/Software/wmaee/wmaee/tests/run_vasp_locally.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from wmaee.core.interfaces.calculation import VaspCalculation
#
# File ~/Software/wmaee/wmaee/core/interfaces/calculation.py:12
#      10 from ase import Atoms
#      11 from ase.calculators.vasp import Vasp
# ---> 12 from ase.md.md import MolecularDynamics
#      13 from ase.calculators.calculator import Calculator
#      14 from ase.io.trajectory import TrajectoryReader, TrajectoryWriter
#
# File ~/Software/anaconda3/lib/python3.8/site-packages/ase/md/__init__.py:4
#       1 """Molecular Dynamics."""
#       3 from ase.md.logger import MDLogger
# ----> 4 from ase.md.verlet import VelocityVerlet
# ...
